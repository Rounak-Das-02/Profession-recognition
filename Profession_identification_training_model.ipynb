# %% [markdown]
# <a href="https://colab.research.google.com/github/Rounak-Das-02/Profession-recognition/blob/master/Profession_identification_training_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install imageai --upgrade
# !pip3 install tensorflow==1.15.2
# !pip3 install keras
import os
from imageai.Prediction.Custom import ModelTraining

# %%
import tensorflow as tf
import keras

# %%
# !git clone https://github.com/Rounak-Das-02/Profession-recognition.git
# Out:
# fatal: destination path 'Profession-recognition' already exists and is not an empty directory.

# %%
model_trainer = ModelTraining()
model_trainer.setModelTypeAsResNet()
model_trainer.setDataDirectory("/content/Profession-recognition/idenprof")

model_trainer.trainModel(num_objects=10, num_experiments=100, batch_size = 32 , enhance_data=True,show_network_summary=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 112, 112, 64) 9472        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 112, 112, 64) 256         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 112, 112, 64) 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# ...
